# %%
from brian2 import *
import time
import matplotlib.pyplot as plt

# %%
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

viridis = cm.get_cmap('cividis', 16)
print(viridis)

# %%
import pickle5 as pickle

with open('/Users/giovanni/Documents/GitHub/fufo/data/Interim/Abhirup/Carmela/Population_regime1.pkl', 'rb') as f:
    Population = pickle.load(f)

# %%
path='/Users/giovanni/Documents/GitHub/fufo/data/Interim/Abhirup/Figures/Fig4/'

# %%
# Carmela

Par = {'Cnap': 21.0,  # mol.m**-3 
       'DCnap': 2.0,  # mol.m**-3 
       'Ckp': 5.5,  # mol.m**-3 
       'DCkp': 1.0,  # mol.m**-3 
       'Cmna': -24.0,  # mV 
       'DCmna': 12.0,  # mV 
       'Chn': 0.4,  # dimensionless 
       'DChn': -8.0,  # dimensionless 
       'Cnk': -19.0,  # mV 
       'DCnk': 18.0,  # mV #Ok in the paper
       'g_Cl': 7.5,  # nS #Ok in the paper
       'g_Na': 40.0,  # nS 
       'g_K': 22.0,  # nS 
       'g_Nal': 0.02,  # nS 
       'g_Kl': 0.12,  # nS 
       'rho': 250.,  # 250.,#pamp 
       'w_i': 2160.0,  # umeter 
       'w_o': 720.0,  # umeter 
       'K_bath': 12.5,  # mol.m**-3
       'Na_i0': 16.0,  # mol.m**-3 
       'Na_o0': 138.0,  # mol.m**-3 
       'K_i0': 130.0,  # mol.m**-3 
       'K_o0': 4.80,  # mol.m**-3 
       'Cl_o0': 112.0,  # mol.m**-3 
       'Cl_i0': 5.0,  # mol.m**-3 
       'E': 0., #check
       
       ## Time costants
       'Cm': 1,#10, #1
       'tau_n': 4,#2.5,#4 
       'gamma': 0.04,  
       'epsilon': 0.001,
       'tau_I': 1
      }

# %%
r=Population[15.5]['x'][-9000:]
V=np.mean(Population[15.5]['V'],axis=0)[-9000:]
n=Population[15.5]['n'][-9000:]
DKi=Population[15.5]['DK_i'][-9000:]
Kg=Population[15.5]['Kg'][-9000:]

# %%
# fig = plt.figure(figsize=(4,3.8))
# ax1 = fig.add_subplot(511)
# ax1.plot(r,c=viridis(5),linewidth=1)
# ax1.spines["top"].set_visible(False)
# ax1.spines["bottom"].set_visible(False)
# ax1.spines["right"].set_visible(False)
# ax1.set_xticks([])
# ax1.tick_params(axis='both',labelsize=8)

# ax1 = fig.add_subplot(512)
# ax1.plot(V,c=viridis(6),linewidth=1)
# ax1.spines["top"].set_visible(False)
# ax1.spines["bottom"].set_visible(False)
# ax1.spines["right"].set_visible(False)
# ax1.set_xticks([])
# ax1.tick_params(axis='both',labelsize=8)

# ax1 = fig.add_subplot(513)
# ax1.plot(n,c=viridis(7),linewidth=1)
# ax1.spines["top"].set_visible(False)
# ax1.spines["bottom"].set_visible(False)
# ax1.spines["right"].set_visible(False)
# ax1.set_xticks([])
# ax1.tick_params(axis='both',labelsize=8)

# ax1 = fig.add_subplot(514)
# ax1.plot(DKi,c=viridis(8),linewidth=1)
# ax1.spines["top"].set_visible(False)
# ax1.spines["bottom"].set_visible(False)
# ax1.spines["right"].set_visible(False)
# ax1.set_xticks([])
# ax1.tick_params(axis='both',labelsize=8)

# ax1 = fig.add_subplot(515)
# ax1.plot(Kg,c=viridis(9),linewidth=1)
# ax1.spines["top"].set_visible(False)
# ax1.spines["bottom"].set_visible(False)
# ax1.spines["right"].set_visible(False)
# ax1.set_xticks([])
# ax1.tick_params(axis='both',labelsize=8)

# plt.tight_layout()
# plt.savefig(path+'Fig3_Population.pdf')
# plt.show()

# %%
fig = plt.figure(figsize=(3.8,2.))

ax1 = fig.add_subplot(311)
ax1.plot(n,c=viridis(2),linewidth=1)
ax1.spines["top"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.set_xticks([])
ax1.tick_params(axis='both',labelsize=6)

ax1 = fig.add_subplot(312)
ax1.plot(DKi,c=viridis(3),linewidth=1)
ax1.spines["top"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.set_xticks([])
ax1.tick_params(axis='both',labelsize=6)

ax1 = fig.add_subplot(313)
ax1.plot(Kg,c=viridis(4),linewidth=1)
ax1.spines["top"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.set_xticks([])
ax1.tick_params(axis='both',labelsize=6)

plt.tight_layout()
plt.savefig(path+'Fig3_Population.pdf')
plt.show()

# %%
# fig = plt.figure(figsize=(3.8,1.))

# ax1 = fig.add_subplot(111)
# ax1.plot(n,c=viridis(2),linewidth=0.75)
# ax1.spines["top"].set_visible(False)
# ax1.spines["bottom"].set_visible(False)
# ax1.spines["right"].set_visible(False)
# ax1.set_xticks([])
# ax1.tick_params(axis='both',labelsize=8)

# plt.tight_layout()
# plt.savefig(path+'Fig3_Population.pdf')
# plt.show()

# %%
Raster=Population[15.5]['V'][:,-9000:]

# %%
Raster.shape
# Out:
# (3000, 9000)

# %%
beta= Par['w_i'] / Par['w_o']
Kext = Par['K_o0'] + -beta * DKi + Kg

fig = plt.figure(figsize=(3.8,1.8))

ax1 = fig.add_subplot(211)
ax1.plot(np.mean(Raster,axis=0),c='#0032cb',linewidth=1)
ax1.spines["top"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.set_xticks([])
ax1.tick_params(axis='both',labelsize=6)

ax1 = fig.add_subplot(212)
ax1.plot(Kext,c='#65cc00',linewidth=1)
ax1.spines["top"].set_visible(False)
ax1.spines["bottom"].set_visible(False)
ax1.spines["right"].set_visible(False)
ax1.set_xticks([])
ax1.tick_params(axis='both',labelsize=6)

plt.tight_layout()
plt.savefig(path+'Fig3_Single_pop.pdf')
plt.show()

# %%
plt.figure(figsize=(3.5,2.))
plt.imshow(np.where(Raster>-0,1,0)[:,:],aspect='auto',interpolation='none',cmap='bone_r')
plt.xticks([])
plt.yticks([])
#plt.axvline(2800)
#plt.axvline(9000-91)
plt.tight_layout()
#plt.savefig(path+'Fig3_Pop_raster.png',dpi=300)
plt.show()

# %%
plt.figure(figsize=(3.,1.4))
plt.imshow(np.where(Raster>-0,1,0)[:,:],aspect='auto',interpolation='none',cmap='bone_r')
plt.xticks([])
plt.yticks([])
#plt.axvline(2800)
#plt.axvline(9000-91)
plt.tight_layout()
plt.savefig(path+'Fig3_Pop_raster.png',dpi=300)
plt.show()

# %%
plt.figure(figsize=(3.,1.4))
plt.imshow(np.where(Raster>100,1,0)[:,:],aspect='auto',interpolation='none',cmap='bone_r')
plt.ylabel('# Neurons')
plt.yticks([0,1000,2000,3000],fontsize=5)
plt.xticks([])
plt.axvline(2800)
plt.axvline(9000-91)
plt.tight_layout()
plt.savefig(path+'Fig3_Pop_ticks.png',dpi=300)
plt.show()

# %%
viridis = cm.get_cmap('cividis', 16)

# %%
viridis = cm.get_cmap('cividis', 16)

# %%
fig, ax = plt.subplots(figsize=(2.25,1.8))
#plt.title('Distribution at time red line')
#ax.hist(MG1.V[:,-309],200,alpha=0.8,color='#BDC2BF')#D0A98F
#ax.hist(Raster[:,2800],200,alpha=1,color='#E3E7D3')#D0A98F
ax.hist(Raster[:,-91],20,alpha=0.9,color='darkslategray')
#ax.hist(Raster[:,4550],200,alpha=0.65,color='r')#989C94')#4D243D
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.set_xticks([0,1,2,3,4])
ax.set_xlim(-1.,4)
ax.tick_params(axis='both',labelsize=7)
ax.set_yticks([])
plt.tight_layout()
plt.savefig(path+'Fig4_hist2.pdf',dpi=300,transparent=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(2.25,1.8))
#plt.title('Distribution at time red line')
#ax.hist(MG1.V[:,-309],200,alpha=0.8,color='#BDC2BF')#D0A98F
#ax.hist(Raster[:,2800],200,alpha=1,color='#E3E7D3')#D0A98F
ax.hist(Raster[:,-91],20,alpha=0.75,color=viridis(2))#989C94')#4D243D
#ax.hist(Raster[:,4550],200,alpha=0.65,color='r')#989C94')#4D243D
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
ax.set_xticks([0,-70,-65,-60])
ax.set_xlim(-1.,4)
ax.tick_params(axis='both',labelsize=7)
ax.set_yticks([])
plt.tight_layout()
plt.savefig(path+'Fig3_hist2.pdf',dpi=300,transparent=True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(2.25,1.8))
#plt.title('Distribution at time red line')
ax.hist(Raster[:,2800],200,alpha=0.9,color='darkslategray')#D0A98F
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)
#ax.set_xticks([-75,-70,-65,-60])
ax.set_xlim(-77,-69)
ax.tick_params(axis='both',labelsize=7)
ax.set_yticks([])
plt.tight_layout()
plt.savefig(path+'Fig4_hist1.pdf',dpi=300,transparent=True)
plt.show()

# %%
plt.figure(figsize=(4.6,3))
#plt.title('Raster plot Mean Membrane potentials V_i')
plt.imshow(Raster,aspect='auto',interpolation='nearest',cmap='viridis')
#plt.ylabel('# Neurons',fontsize='14')
plt.xlabel('Time (seconds)',fontsize='14')
plt.yticks([0,2900],[0,3000])
#plt.xticks(np.arange(3300)[::300],np.round(np.linspace(0,6,11),1))
plt.colorbar()
plt.tight_layout()
#plt.savefig('Population_raster.pdf')
plt.show()

# %%
from scipy import stats

# %%
import pickle

def save_obj(obj, name ):
    with open('/Users/giovanni/Documents/GitHub/fufo/data/Interim/Abhirup/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

# %%
Pop={'V':MG1.V}

# %%
save_obj(Pop,'Fig4_Population_75')
